# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gdp
from shapely.geometry import Point
# %matplotlib inline
import fiona
import folium
from pandas.io.json import json_normalize

# %%
adr = 'https://opendata.arcgis.com/datasets/b81aeb7bc2914fa5868e6a961040065a_0.geojson'
df = gdp.read_file(adr)

# %%
df = df.fillna(0)

# %%
ax = df.plot(column='Cases',figsize=(20,20), 
             edgecolor='white', linewidth=0.25)
ax.axis('Off')
# Out:
# (93.2579293006638, 171.5570876422744, -45.47038090530948, -7.412596741849458)
